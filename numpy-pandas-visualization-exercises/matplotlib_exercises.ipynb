# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def quadratic_function(x):    #the quadratic_function of x is y
    return x**2-x+2
x_values= np.linspace(-5,5,50)  #-5 to 5 is the range and 50 is what to generate
y_values= quadratic_function(x_values) #set the y value to what was defined earlier
plt.plot(x_values,y_values,color='black',label='Thoai\'s Graph')

# x values, y values, and plot customization has been defined
#we can now plot the x, and y label
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y=x^2-x+2')

plt.show()
